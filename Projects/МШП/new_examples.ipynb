# %%
import pandas as pd
import json

# %%
with open('fifa_data.json','r') as f:
    data = f.read()
    data = json.loads(data)

# %%
df = pd.DataFrame(data['matches'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 22 columns):
# attendance              64 non-null object
# away_team               64 non-null object
# away_team_country       64 non-null object
# away_team_events        64 non-null object
# away_team_statistics    64 non-null object
# datetime                64 non-null object
# fifa_id                 64 non-null object
# home_team               64 non-null object
# home_team_country       64 non-null object
# home_team_events        64 non-null object
# home_team_statistics    64 non-null object
# last_event_update_at    64 non-null object
# last_score_update_at    61 non-null object
# location                64 non-null object
# officials               64 non-null object
# stage_name              64 non-null object
# status                  64 non-null object
# time                    64 non-null object
# venue                   64 non-null object
# ...

# %%
df.head()
# Out:
#   attendance                                          away_team  \
# 0      78011  {'country': 'Saudi Arabia', 'code': 'KSA', 'go...
# 1      27015  {'country': 'Uruguay', 'code': 'URU', 'goals':...
# 2      62548  {'country': 'Iran', 'code': 'IRN', 'goals': 1,...
# 3      43866  {'country': 'Spain', 'code': 'ESP', 'goals': 3...
# 4      41279  {'country': 'Australia', 'code': 'AUS', 'goals...
#
#   away_team_country                                   away_team_events  \
# 0      Saudi Arabia  [{'id': 12, 'type_of_event': 'substitution-in'...
# 1           Uruguay  [{'id': 15, 'type_of_event': 'substitution-in'...
# 2              Iran  [{'id': 22, 'type_of_event': 'yellow-card', 'p...
# 3             Spain  [{'id': 37, 'type_of_event': 'yellow-card', 'p...
# 4         Australia  [{'id': 50, 'type_of_event': 'yellow-card', 'p...
#
#                                 away_team_statistics              datetime  \
# ...

# %%
df.weather[0]
# Out:
# {'humidity': '43',
#  'temp_celsius': '17',
#  'temp_farenheit': '49',
#  'wind_speed': '6',
#  'description': 'Partly Cloudy'}

# %%
df['temp_cels'] = df.weather.apply(lambda x:x['temp_celsius']).astype(float)

# %%
df.head()
# Out:
#   attendance                                          away_team  \
# 0      78011  {'country': 'Saudi Arabia', 'code': 'KSA', 'go...
# 1      27015  {'country': 'Uruguay', 'code': 'URU', 'goals':...
# 2      62548  {'country': 'Iran', 'code': 'IRN', 'goals': 1,...
# 3      43866  {'country': 'Spain', 'code': 'ESP', 'goals': 3...
# 4      41279  {'country': 'Australia', 'code': 'AUS', 'goals...
#
#   away_team_country                                   away_team_events  \
# 0      Saudi Arabia  [{'id': 12, 'type_of_event': 'substitution-in'...
# 1           Uruguay  [{'id': 15, 'type_of_event': 'substitution-in'...
# 2              Iran  [{'id': 22, 'type_of_event': 'yellow-card', 'p...
# 3             Spain  [{'id': 37, 'type_of_event': 'yellow-card', 'p...
# 4         Australia  [{'id': 50, 'type_of_event': 'yellow-card', 'p...
#
#                                 away_team_statistics              datetime  \
# ...

# %%
df.temp_cels.mean()
# Out:
# 23.75

# %%
df['tactics'].value_counts()
# Out:
# 4-2-3-1    33
# 4-4-2      10
# 3-4-3       6
# 3-5-2       5
# 4-3-3       4
# 4-5-1       3
# 4-3-2-1     1
# 3-4-2-1     1
# 5-4-1       1
# Name: tactics, dtype: int64

# %%
df.groupby('venue')['temp_cels'].mean()
# Out:
# venue
# Ekaterinburg       19.500000
# Kaliningrad        17.750000
# Kazan              23.166667
# Moscow             22.916667
# Nizhny Novgorod    23.166667
# Rostov-On-Don      29.000000
# Samara             27.333333
# Saransk            22.000000
# Sochi              25.166667
# St. Petersburg     20.428571
# Volgograd          31.750000
# Name: temp_cels, dtype: float64
