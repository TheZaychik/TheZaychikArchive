# %%
import pandas as pd
df = pd.read_csv('titanic.csv')

# %%
df
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson, Mr. Harry
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 7          1         0                             Andrews, Mr. Thomas Jr
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia, Mr. Ramon
# 10         1         0                             Astor, Col. John Jacob
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
df['sex'].value_counts()
# Out:
# male      843
# female    466
# Name: sex, dtype: int64

# %%
df[(df['sex'] == 'male') & (df['survived'] == 1)].sort_values(by='age')
# Out:
#       pclass  survived                                               name  \
# 1240       3         1                    Thomas, Master. Assad Alexander
# 427        2         1                          Hamalainen, Master. Viljo
# 611        3         1                          Aks, Master. Philip Frank
# 548        2         1                    Richards, Master. George Sibley
# 359        2         1                      Caldwell, Master. Alden Gates
# 1          1         1                     Allison, Master. Hudson Trevor
# 762        3         1                         Dean, Master. Bertram Vere
# 492        2         1                              Mallet, Master. Andre
# 339        2         1                          Becker, Master. Richard F
# 587        2         1                        Wells, Master. Ralph Lester
# 514        2         1                     Navratil, Master. Edmond Roger
# 734        3         1             Coutts, Master. William Loch "William"
# ...

# %%
df['survived'].sum()
# Out:
# 500

# %%
df[(df['sex'] == 'female')& (df['sibsp'] == 0)& (df['parch'] == 0) & (df['age'] < 25)].shape
# Out:
# (63, 14)

# %%
df[(df['sibsp'] == 0)& (df['parch'] == 0)].sort_values(by='fare')
# Out:
#       pclass  survived                                               name  \
# 1241       3         0                              Thomas, Mr. Charles P
# 1289       3         0                            Wiklund, Mr. Karl Johan
# 1288       3         0                          Wiklund, Mr. Jakob Alfred
# 1290       3         1                   Wilkes, Mrs. James (Ellen Needs)
# 688        3         0                          Braund, Mr. Lewis Richard
# 885        3         0                          Jensen, Mr. Svend Lauritz
# 689        3         0                            Braund, Mr. Owen Harris
# 929        3         0                                  Kiernan, Mr. John
# 930        3         0                                Kiernan, Mr. Philip
# 1129       3         0                          Petterson, Mr. Johan Emil
# 1120       3         1                           Persson, Mr. Ernst Ulrik
# 849        3         0                            Hansen, Mr. Henrik Juul
# ...

# %%
df[df['boat'] == '11'].sum()
# Out:
# pclass                                                     49
# survived                                                   25
# name        Allison, Master. Hudson TrevorCleaver, Miss. A...
# sex         malefemalemalefemalefemalefemalefemalemalefema...
# age                                                    530.75
# sibsp                                                      12
# parch                                                      13
# ticket      11378111378113236PC 17613132361350722687523013...
# fare                                                  941.221
# embarked                            SSCCCSSSSSSSCSSSSSSSSSSSS
# boat        1111111111111111111111111111111111111111111111...
# body                                                        0
# dtype: object

# %%
t = pd.DataFrame()
t['male_1'] = df[(df['sex'] == 'male') & (df['pclass'] == 1)].sum()
t['male_2'] = df[(df['sex'] == 'male') & (df['pclass'] == 2)].sum()
t['male_3'] = df[(df['sex'] == 'male') & (df['pclass'] == 3)].sum()
t['female_1'] = df[(df['sex'] == 'female') & (df['pclass'] == 1)].sum()
t['female_2'] = df[(df['sex'] == 'female') & (df['pclass'] == 2)].sum()
t['female_3'] = df[(df['sex'] == 'female') & (df['pclass'] == 3)].sum()
t
# Out:
#                                                      male_1  \
# pclass                                                  179
# survived                                                 61
# name      Allison, Master. Hudson TrevorAllison, Mr. Hud...
# sex       malemalemalemalemalemalemalemalemalemalemalema...
# age                                                 6195.42
# sibsp                                                    61
# parch                                                    50
# ticket    11378111378119952112050PC 17609PC 1775727042PC...
# fare                                                  12510
# embarked  SSSSCCSSCCSCCCSSCSSSCCSSSCSSSSSSSSSCSCSSCSSCSS...
# body                                                   5699
#
#                                                      male_2  \
# pclass                                                  342
# survived                                                 25
# name      Abelson, Mr. SamuelAldworth, Mr. Charles Augus...
# ...

# %%
t = pd.DataFrame()
t['m_age'] = df[df['sex'] == 'male'].mean()
t['f_age'] = df[df['sex'] == 'female'].mean()
t
# Out:
#                m_age       f_age
# pclass      2.372479    2.154506
# survived    0.190985    0.727468
# age        30.585228   28.687088
# sibsp       0.413998    0.652361
# parch       0.247924    0.633047
# fare       26.154601   46.198097
# body      160.398230  166.625000

# %%
df['boat'].value_counts().mean()
# Out:
# 18.0

# %%
df.groupby('pclass')['fare'].value_counts().sort_values()
# Out:
# pclass  fare
# 2       10.7083     1
# 1       49.5000     1
# 2       9.6875      1
# 3       10.1708     1
# 2       12.0000     1
#         12.2750     1
#         12.5250     1
#         12.6500     1
#         12.7375     1
#         13.7917     1
#         14.0000     1
#         15.0000     1
#         15.0333     1
#         15.0500     1
#         15.5792     1
# 3       3.1708      1
# 1       45.5000     1
#         42.5000     1
#         40.1250     1
#         38.5000     1
#         25.7000     1
#         25.7417     1
#         25.9250     1
#         26.2833     1
#         26.3875     1
#         27.4458     1
#         27.7500     1
# 3       4.0125      1
# 1       28.5375     1
#         31.6792     1
#                    ..
# 3       7.5500      8
#         46.9000     8
# 1       26.0000     8
# 3       15.2458     9
#         14.5000     9
#         7.0500      9
#         24.1500     9
# 1       27.7208     9
# 3       7.7958     10
#         7.8792     10
# ...

# %%
df['home.dest'].value_counts().sort_values()
# Out:
# Syria Youngstown, OH                          1
# Folkstone, Kent / New York, NY                1
# Omaha, NE                                     1
# Kingston, Surrey                              1
# Haddenfield, NJ                               1
# Upper Burma, India Pittsburgh, PA             1
# Treherbert, Cardiff, Wales                    1
# Belfast, NI                                   1
# St Andrews, Guernsey                          1
# Weston-Super-Mare / Moose Jaw, SK             1
# Windsor, England New York, NY                 1
# Hamilton, ON                                  1
# Hornsey, England                              1
# Bennington, VT                                1
# London New York, NY                           1
# Catford, Kent / Detroit, MI                   1
# Co Cork, Ireland Roxbury, MA                  1
# Barre, Co Washington, VT                      1
# Guernsey, England / Edgewood, RI              1
# Merrill, WI                                   1
# ...

# %%
####  А Н А Л И З
t, d = pd.DataFrame(), pd.DataFrame()
t = df[df['survived'] == 0]
d = df[df['survived'] == 1]
t
# Out:
#       pclass  survived                                               name  \
# 2          1         0                       Allison, Miss. Helen Loraine
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 7          1         0                             Andrews, Mr. Thomas Jr
# 9          1         0                            Artagaveytia, Mr. Ramon
# 10         1         0                             Astor, Col. John Jacob
# 15         1         0                                Baumann, Mr. John D
# 16         1         0                           Baxter, Mr. Quigg Edmond
# 19         1         0                               Beattie, Mr. Thomson
# 25         1         0                                Birnbaum, Mr. Jakob
# 30         1         0                       Blackwell, Mr. Stephen Weart
# 34         1         0                           Borebank, Mr. John James
# ...

# %%
d
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         1                     Allison, Master. Hudson Trevor
# 5          1         1                                Anderson, Mr. Harry
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12         1         1                      Aubart, Mme. Leontine Pauline
# 13         1         1                       Barber, Miss. Ellen "Nellie"
# 14         1         1               Barkworth, Mr. Algernon Henry Wilson
# 17         1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 18         1         1                              Bazzani, Miss. Albina
# 20         1         1                      Beckwith, Mr. Richard Leonard
# ...
