# %%
import pandas as pd
import numpy as np
from sklearn import datasets
import statsmodels.formula.api as smf
df = pd.read_csv('Flats.csv', sep=';')
df
# Out:
#          n  price  totsp  livesp kitsp  ...  metrdist  walk  brick  floor  code
# 0      1.0   75.0   44.0    28.0     6  ...       7.0   1.0    0.0    1.0   6.0
# 1      2.0   95.0   61.0    37.0     6  ...       7.0   1.0    0.0    1.0   1.0
# 2      3.0   88.0   55.0    36.0     6  ...       5.0   1.0    1.0    0.0   4.0
# 3      4.0  225.0   80.0    56.0     9  ...       5.0   1.0    1.0    1.0   3.0
# 4      5.0  140.0   86.0    51.0    10  ...      10.0   1.0    0.0    1.0   5.0
# 5      6.0  132.0   96.0    56.0    12  ...       7.0   0.0    0.0    1.0   3.0
# 6      7.0  115.0   77.0    50.0     9  ...       7.0   1.0    0.0    0.0   7.0
# 7      8.0  170.0   87.0    58.0     8  ...       7.0   1.0    1.0    1.0   3.0
# 8      9.0  170.0   84.0    55.0    11  ...      15.0   1.0    1.0    0.0   1.0
# 9     10.0   95.0   58.0    38.0     6  ...       8.0   1.0    0.0    1.0   1.0
# 10    11.0  148.0   92.0    61.0    10  ...      15.0   1.0    1.0    1.0   7.0
# ...

# %%
est = smf.ols(data=df, formula='price ~ totsp + livesp + kitsp + dist + metrdist')
res = est.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.717
# Model:                            OLS   Adj. R-squared:                  0.705
# Method:                 Least Squares   F-statistic:                     57.78
# Date:                Sun, 16 Dec 2018   Prob (F-statistic):          1.18e-230
# Time:                        19:04:34   Log-Likelihood:                -4799.4
# No. Observations:                1000   AIC:                             9685.
# Df Residuals:                     957   BIC:                             9896.
# Df Model:                          42
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept      -65.5529     11.240     -5.832      0.000     -87.611     -43.495
# ...
